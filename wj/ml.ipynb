# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, roc_auc_score
from sklearn.metrics import f1_score, confusion_matrix, precision_recall_curve, roc_curve
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

diabetes_data = pd.read_csv('../cars.csv')
#print(diabetes_data['가격'].value_counts())
diabetes_data.head(3)
# Out:
# 가격
# [가격상담]     859
# 0원         100
# 699만원       26
# 700만원       24
# 2,799만원     20
#           ...
# 1,550만원      2
# 1,540만원      2
# 3,870만원      2
# 1786만원       1
# 6,400만원      1
# Name: count, Length: 227, dtype: int64
#    Unnamed: 0                                  이름           차량번호  \
# 0           0  현대 그랜저IG 하이브리드 2.4 HEV  익스클루시브 스페셜   차량번호 37누3541
# 1           1      현대 더 뉴 그랜저 하이브리드 2.4 HEV 캘리그래피  차량번호 156마6718
# 2           2           현대 더 뉴 그랜저 3.0 LPi   프리미엄  차량번호 153오1506
#
#                                                   링크              연식  \
# 0  https://www.bobaedream.co.kr/mycar/mycar_view....  2017.05?(18년형)
# 1  https://www.bobaedream.co.kr/mycar/mycar_view....  2020.11?(21년형)
# 2  https://www.bobaedream.co.kr/mycar/mycar_view....  2021.09?(22년형)
#
#         주행거리         연료               배기량   색상              보증정보  ... 보험이력등록  \
# 0  70,530 km  가솔린 하이브리드  2,359 cc (199마력)  검정색                만료  ...     등록
# 1  46,128 km  가솔린 하이브리드  2,359 cc (200마력)  진회색  60개월 / 100,000km  ...     등록
# 2  21,062 km        LPG  2,999 cc (235마력)   흰색              정보없음  ...     등록
#
#   소유자변경횟수 사고상세_전손 사고상세_침수전손 사고상세_침수분손 사고상세_도난 보험_내차피해(횟수) 보험_내차피해(가격)  \
# 0     NaN     NaN       NaN       NaN     NaN         NaN         NaN
# 1     NaN     NaN       NaN       NaN     NaN         NaN         NaN
# 2     NaN     NaN       NaN       NaN     NaN         NaN         NaN
#
#   사고상세_타차가해(횟수) 보험_타차피해(가격)
# 0           NaN         NaN
# 1           NaN         NaN
# 2           NaN         NaN
#
# [3 rows x 32 columns]

# %%
diabetes_data.info( )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2484 entries, 0 to 2483
# Data columns (total 32 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     2484 non-null   int64
#  1   이름             2484 non-null   object
#  2   차량번호           2484 non-null   object
#  3   링크             2484 non-null   object
#  4   연식             2484 non-null   object
#  5   주행거리           2484 non-null   object
#  6   연료             2484 non-null   object
#  7   배기량            2484 non-null   object
#  8   색상             2484 non-null   object
#  9   보증정보           2484 non-null   object
#  10  가격             2484 non-null   object
#  11  신차대비가격         2484 non-null   object
#  12  옵션_선루프         2051 non-null   object
#  13  옵션_파노라마선루프     2051 non-null   object
#  14  옵션_열선앞         2051 non-null   object
#  15  옵션_열선뒤         2051 non-null   object
#  16  옵션_전방센서        2051 non-null   object
#  17  옵션_후방센서        2051 non-null   object
#  18  옵션_전방캠         2051 non-null   object
#  19  옵션_후방캠         2051 non-null   object
#  20  옵션_어라운드뷰       2051 non-null   object
#  21  옵션_네비순정        2051 non-null   object
#  22  보험이력등록         2484 non-null   object
#  23  소유자변경횟수        0 non-null      float64
#  24  사고상세_전손        0 non-null      float64
#  25  사고상세_침수전손      0 non-null      float64
#  26  사고상세_침수분손      0 non-null      float64
#  27  사고상세_도난        0 non-null      float64
#  28  보험_내차피해(횟수)    0 non-null      float64
#  29  보험_내차피해(가격)    0 non-null      float64
#  30  사고상세_타차가해(횟수)  0 non-null      float64
#  31  보험_타차피해(가격)    0 non-null      float64
# dtypes: float64(9), int64(1), object(22)
# memory usage: 621.1+ KB
